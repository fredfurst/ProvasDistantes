# %% [markdown]
# # Vigas no Método dos Deslocamentos

# %% [markdown]
# Frederico Furst Bittencourt

# %% [markdown]
# 15 de abril de 2020

# %%
import sympy as sy
import numpy as np
from IPython.display import Image

# %% [markdown]
# ## A07ExAc1

# %%
Image("Annotation 2020-04-15 111748.jpg", width=600)

# %%
E,I,P,p = sy.symbols('E I P p')

# %% [markdown]
# ### Rigidez

# %%
Image("Annotation 2020-04-15 113201.jpg", width=200)

# %%
k = 4*E*I/9

# %%
k
# Out:
# 4*E*I/9

# %% [markdown]
# ### Termos de Carga

# %%
Image("Annotation 2020-04-15 112017.jpg", width=800)

# %% [markdown]
# #### Carregamento Distribuído

# %%
Image("Annotation 2020-04-15 111921.jpg", width=800)

# %%
Mcd_p = p*5**2/12/9**2*(6*4**2+4*4*5+5**2)

# %%
Mcd_p
# Out:
# 1675*p/324

# %%
Mdc_p = -p*5**2/12/9**2*(4*4*5+5**2)

# %%
Mdc_p
# Out:
# -875*p/324

# %% [markdown]
# #### Carga Concentrada

# %%
Image("Annotation 2020-04-15 112208.jpg", width=800)

# %%
Mcd_P = P*7*2**2/9**2

# %%
Mcd_P
# Out:
# 28*P/81

# %%
Mdc_P = -P*7**2*2/9**2

# %%
Mdc_P
# Out:
# -98*P/81

# %% [markdown]
# ### Sistema de Equações na Superposição

# %% [markdown]
# $$k \times D_1+F=0 $$

# %%
k
# Out:
# 4*E*I/9

# %% [markdown]
# $$F = - \frac{pc^2}{12l^2}(4bc+c^2)-\frac{Pa^2b}{l^2}$$

# %% [markdown]
# Calculando o deslocamento da deslocabilidade $D_1$:

# %%
F=Mdc_p+Mdc_P

# %%
F
# Out:
# -98*P/81 - 875*p/324

# %%
D1 = -F/k

# %%
D1
# Out:
# 9*(98*P/81 + 875*p/324)/(4*E*I)

# %%
D1.subs([(P,35),(p,8)]) # substituindo P = 35kN e p = 8kN/m
# Out:
# 1295/(9*E*I)

# %%
1295/9
# Out:
# 143.88888888888889

# %% [markdown]
# ### Reações de Apoio

# %% [markdown]
# <p>Convenção de sinais:
# <p>$M_A = \frac{2EI}{L}D_1 + M_{CD,p} + M_{CD,P}$ positivo no sentido anti-horário
# <p>$R_{Ay} = \frac{6EI}{L^2}D_1 + \frac{Pab^2}{L^2}\frac{1}{L} + \frac{pc^2}{12L^2}\frac{6b^2+4bc+c^2}{L}$ positivo para cima
# <p>$R_{By} = -\frac{6EI}{L^2}D_1 + \frac{Pa^2b}{L^2}\frac{1}{L} + \frac{pc^2}{12L^2}\frac{4bc+c^2}{L}$ positivo para cima

# %% [markdown]
# Momento-fletor em A $M_A$:

# %%
M_A = 2*E*I/9*D1 + Mcd_p + Mcd_P

# %%
M_A
# Out:
# 77*P/81 + 4225*p/648

# %%
M_A.subs([(p,8),(P,35)])
# Out:
# 6920/81

# %%
6920/81
# Out:
# 85.4320987654321

# %% [markdown]
# Reação Vertical em A $R_{Ay}$:

# %%
R_Ay = 6*E*I/9**2*D1 + Mcd_P/9 + Mcd_p/9 - Mdc_P/9 - Mdc_p/9

# %%
R_Ay
# Out:
# 91*P/243 + 2575*p/1944

# %%
R_Ay.subs([(p,8),(P,35)])
# Out:
# 640/27

# %%
640/27
# Out:
# 23.703703703703702

# %% [markdown]
# Reação Vertical em B $R_{By}$:

# %%
(-6*E*I/9**2*D1).subs([(p,8),(P,35)])
# Out:
# -2590/243

# %%
2590/243
# Out:
# 10.65843621399177

# %%
R_By = -6*E*I/9**2*D1 - Mcd_P/9 - Mcd_p/9 + Mdc_P/9 + Mdc_p/9

# %%
R_By
# Out:
# -91*P/243 - 2575*p/1944

# %%
R_By.subs([(p,8),(P,35)])
# Out:
# -640/27

# %%
640/27
# Out:
# 23.703703703703702

# %%
Mcd_P/9 + Mcd_p/9
# Out:
# 28*P/729 + 1675*p/2916

# %%
(Mcd_P/9 + Mcd_p/9).subs([(p,8),(P,35)])
# Out:
# 3170/243

# %%
3170/243
# Out:
# 13.045267489711934

# %%
-Mdc_P/9 - Mdc_p/9
# Out:
# 98*P/729 + 875*p/2916

# %%
(-Mdc_P - Mdc_p).subs([(p,8),(P,35)])
# Out:
# 5180/81

# %%
5180/81/9
# Out:
# 7.10562414266118
